# %% [markdown]
# # CNN (Convolutional Neural Network)

# %% [raw]
# how does a computer reconize image ?
#
# an image is just numbers(pixels)
# like 28*28 -> 784 pixels
#
# if we give this to normal ANN(MLP):
#     too many connections.
#     too slow
#     can't understan shape or patterns
#
# it is a neural network specifically designe for images
# looks at small parts of image
# learns edges, shapes , patterns
# combines them to understna the full image
#
# why cnn->
# traditional ANN traets al pixels equally
#
# key idea-> nearby pixels are related
# looks at small regions
# learns local patterns first
#
# 1. convolutional layer (feature detector):->
# think as pattern scanner
# use a small matrix called filter
#
# 2. Pooling layer-> (Size reducer)
# keeps important info
# amkes model faster
# most common type->> Max pooling keeps maximum value.
#
# ****why relu activation function-> used when we have MLP , basicallu multi layer -> giving good accuracy-> proovide faster computational faster
#
# 3. fully connected layer -> (Decision layer)
# takes extracted features
# makes final decision
#
# image -> convolutional -> pooling -> fully connected -> output
#
# Applications->
# image clasification
# self driving cars

# %% [markdown]
# # RNN (Recurrent Neural Network)

# %% [markdown]
# type of ANN
# work with sequential data whre order of data matters
# RNN can remember the past data and use it to make the currnet predictions
#
# At each time step:
#     network takes current input
# combine with revious memory
# produces output
# upates memory
#
#
# why->
# ANN or CNN process each input independently.
#     they don't remmeber previous data
#     Predicting stock prices
#     speech recognition
#     Understanding the sentence
#
#
# RNN different->
# fedback looping -> ouput again feed as input to network
# also called feedback neural network
# feedack creates memory, helps RNN understand memory
#
# memory stored in something called hidden state
# hidden layer carries information from previous tiem step
#
# important:
# ANN weights store learned knowlege
# RNN hides state stores temporary sequence information
