# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %% [raw]
#                                             DECISION TREE CLASSIFIER
# it aso works as regression moel, although most of the time it comes under classification model
# at every node, there is a decision
# Terminology->
#     pruning
#     parent/child node
#     root node
#     branch/subtree
#     splitting
#     leaf node

# %% [raw]
#                                             CART ALGORITHM
# entropy -> randomness/uncertainity,
# information gain

# %% [raw]
# Z-test
# T-test
# chi-square test -> when need to compare before and something, comparison occurs
# 2 samples T-test

# %% [raw]
# how does a tree decide where to split
# information gain -> entropy -> measure of impurity or disorder in dataset
# reduction in variance -> used in regression model
# chi square -> comparion betwween observed and actual
# gini index -> calculating th impurity , maximum index-> 0.5
#
# 90% cases we are using entropy method

# %% [raw]
# entropy range is [0,1]
# curve is inverted U shaped
#
# entropy = -P(yes)log2.P(yes) - p(no)log2.P(no)
#
# when P(yes) = P(no) = 0.5
# then entropy = 1
#
# when P(yes) = 1
# entropy = 0
#
# when P(no) = 1
# entropy = 0
#
# then that attribute (having entropy=0) will become the leaf node

# %% [raw]
#                                                         INFORMATION GAIN
# measure the reduction in entropy
# decide which attribute should be selected as decision node
#
# if S is our collective collection
# information gain = entropy(s) - [weighted avg]

# %% [raw]
# E(s) = -P(yes) log2 p(yes) - p(no) log2 p(no)
# E(s) = -(9/14)* log2(9/14) - (5/14) * log2(5/14)
# E(s) = 0.94
#
# entropy of outlook attribute
# sunny = {+2,-3}
#  = 0.97
#
# cloudy = {+4,0}
#  = 0
#
# Rain = {+3,-2}
#  = 0.97
#
# Information gain = 0.94 - 0.6928 = 0.2472
#
# now finding the entropy in case of tempearture
#
# Hot -> 1.0
# Mild -> 0.91
# Cold -> 0.81
#
# Information gain = 0.94 - 0.91 = 0.03
#
# now in case of humidity
#
# High -> 0.98
# Normal -> 0.59
#
# Information gain = 0.94 - 0.785 = 0.155
#
# now in case of wind
# Information gain = 0.0478
#
# so maximum entropy is shown by outlook
# so it will be our root node

# %% [raw]
# Pruning-> graphical represenattion of all possible solutions to a decision based on certain conditions.
#
# basically to reduce the complexity
#
# Gini impurity-> highest value is 0.5
# G = 1 - (Py^2 + Pn^2)
#
# we can say:
# Entropy = 2*Gini
#     GINI IMPURITY
# 1. faster computation as it avoids log operations
# 2. creates split quickly, favouring dominant classes.
# 3. efficient for large, high dimensional datasets
# 4. often default in libraries like CART
# 5. NO labelization is here.
#
#     ENTROPY
# 1. slightly slower due to log operations
# 2. produces more balance node partitions
# 3. useful for structural datasets
# 4. prefered when theoritical information gain matters
# 5. proper labelization is there

# %%
iris = load_iris()
X = iris.data
y = iris.target
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dt = DecisionTreeClassifier(max_depth=5,random_state=42)
dt.fit(X_train,y_train)
y_pred_dt = dt.predict(X_test)
print("Accuracy: ",accuracy_score(y_test,y_pred_dt))
print("Classification Report :\n",classification_report(y_test,y_pred_dt))
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(y_test,y_pred_dt),annot=True,cmap='Purples',fmt='g')
plt.title('Confusion matrx - Decision tree')

plot_tree(dt,filled=True,feature_names=iris.feature_names,class_names = iris.target_names)
plt.show()
# Out:
# Accuracy:  1.0
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dt = DecisionTreeClassifier(criterion='entropy',max_depth=5,random_state=42) # performing the hupertuning and hyperparameters
dt.fit(X_train,y_train)
y_pred_dt = dt.predict(X_test)
print("Accuracy: ",accuracy_score(y_test,y_pred_dt))
print("Classification Report :\n",classification_report(y_test,y_pred_dt))
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(y_test,y_pred_dt),annot=True,cmap='Purples',fmt='g')
plt.title('Confusion matrx - Decision tree')

plot_tree(dt,filled=True,feature_names=iris.feature_names,class_names = iris.target_names) # filled used to show the bars in different colors
plt.show()
# Out:
# Accuracy:  0.9555555555555556
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.87      1.00      0.93        13
#            2       1.00      0.85      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
df = pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
lb = LabelEncoder()
for col in df.columns:
    df[col] = lb.fit_transform(df[col])

df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
X_mush = df.drop('class',axis=1)
y_mush = df['class']

# %%
X_train_mush,X_test_mush,y_train_mush,y_test_mush = train_test_split(X_mush,y_mush,test_size=0.3,random_state=42)

dec = DecisionTreeClassifier(criterion='entropy',max_depth=3,random_state=42)
dec.fit(X_train_mush,y_train_mush)
y_pred_mush = dec.predict(X_test_mush)

print("Accuracy: ",accuracy_score(y_test_mush,y_pred_mush))
print("Classification Report :\n",classification_report(y_test_mush,y_pred_mush))
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(y_test_mush,y_pred_mush),annot=True,cmap='Purples',fmt='g')
plt.title('Confusion matrx - Decision tree')
plt.show()
# Out:
# Accuracy:  0.9532403609515997
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95      1257
#            1       0.93      0.97      0.95      1181
#
#     accuracy                           0.95      2438
#    macro avg       0.95      0.95      0.95      2438
# weighted avg       0.95      0.95      0.95      2438

# %%
plot_tree(dec,filled=True,class_names=["Edible","Poisionous"],rounded=True) # filled used to show the bars in different colors
plt.show()
