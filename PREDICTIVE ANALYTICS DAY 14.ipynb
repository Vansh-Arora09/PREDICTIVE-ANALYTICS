# %% [markdown]
# # UNSUPERVISED LEARNING

# %% [markdown]
# # HIERARCHICAL CLUSTERING

# %% [raw]
# build hierarchy of nested clusters
#
# two main approaches: agglomerative , Divisive
#
# no need to predefined clusters number
#
# Dendogram helps visualize merging process

# %% [raw]
# Dendogram like cluster family tree
#
# show how data points merge together
#
# bottom displays each point as cluster
#
# higher level combine more similar gropus
#
# lower merge points mean higher similarity
#
# Bottom-up approach

# %% [raw]
# divisive - top-down approach
# agglomerative - bottom-up approach

# %% [raw]
# AGGLOMERATIVE APPROACH
#
# each data point act as cluster
# closest custers merge at each point
# uses linkage criteria

# %% [raw]
# DIVISIVE APPROACH
#
# starts with all data a single cluster
# split recursively
# uses dissimilarity to decide splits

# %% [raw]
# How things works ?
#
# Distance matrix computed
# linkage function decide inter-cluster distance
# single- min(dij), complete- max(dij)

# %% [raw]
#                     LINKAGES
#
# single - smallest
# complete - largest
# average = mean distance between clusters
# centroid - distance between cluster centroids

# %% [raw]
# single linkage
# minimum distance method
# long chain like cluster formation
# sensitive to noise and outliers
# good for detecting irregular shaped data clusters
# procedure is like knn -> fining nearest points

# %% [raw]
# complete linkage
# farthest pair distance
# produces compact, spherical, evenly size clusters less affeced by outliers than single linkage

# %% [raw]
# centroid linkage
#
# measure cluster center distance
# measure criteria: || ua - ub ||
# can cause inversions in dendogram hierarchy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import load_iris

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df['species'] = iris.target

# %%
X = df.drop('species',axis=1)
y = df['species']

# %%
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %%
plt.figure(figsize=(10,6))
linked = linkage(X_scaled, method='ward') # ward method minimizes variance within the clusters
dendrogram(linked)
plt.title("Dendrogram for Iris Dataset")
plt.xlabel('Data Points')
plt.ylabel('Euclidean Distance')
plt.show()

# %%
hc = AgglomerativeClustering(n_clusters=3, linkage='ward')
df['cluster'] = hc.fit_predict(X_scaled)

df['cluster']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Name: cluster, Length: 150, dtype: int64

# %%
print(df.groupby(['cluster','species']).size())
# Out:
# cluster  species
# 0        1          23
#          2          48
# 1        0          49
# 2        0           1
#          1          27
#          2           2
# dtype: int64
